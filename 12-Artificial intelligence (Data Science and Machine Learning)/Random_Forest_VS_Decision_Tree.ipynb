# %%
from sklearn.datasets import load_iris
from sklearn import tree
import pandas as pd 
from sklearn.model_selection import train_test_split

# %%
iris = load_iris()
X, Y = iris.data, iris.target
inputs = pd.DataFrame(X, columns=iris.feature_names)
outputs = Y

# %%
X_train , X_test, Y_train, Y_test = train_test_split(inputs,outputs,test_size = 0.2)

# %%
X_train
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 29                 4.7               3.2                1.6               0.2
# 22                 4.6               3.6                1.0               0.2
# 122                7.7               2.8                6.7               2.0
# 146                6.3               2.5                5.0               1.9
# 19                 5.1               3.8                1.5               0.3
# ..                 ...               ...                ...               ...
# 54                 6.5               2.8                4.6               1.5
# 12                 4.8               3.0                1.4               0.1
# 135                7.7               3.0                6.1               2.3
# 116                6.5               3.0                5.5               1.8
# 121                5.6               2.8                4.9               2.0
#
# [120 rows x 4 columns]

# %%
DT = tree.DecisionTreeClassifier()
DT = DT.fit(X_train, Y_train)

# %%
print("accuracy: ",DT.score(X_test,Y_test))
# Out:
# accuracy:  1.0

# %%
tree.plot_tree(DT)
# Out:
# [Text(0.4, 0.9166666666666666, 'x[2] <= 2.45\ngini = 0.666\nsamples = 120\nvalue = [41, 41, 38]'),
#  Text(0.3, 0.75, 'gini = 0.0\nsamples = 41\nvalue = [41, 0, 0]'),
#  Text(0.5, 0.75, 'x[2] <= 4.95\ngini = 0.499\nsamples = 79\nvalue = [0, 41, 38]'),
#  Text(0.2, 0.5833333333333334, 'x[3] <= 1.65\ngini = 0.133\nsamples = 42\nvalue = [0, 39, 3]'),
#  Text(0.1, 0.4166666666666667, 'gini = 0.0\nsamples = 38\nvalue = [0, 38, 0]'),
#  Text(0.3, 0.4166666666666667, 'x[1] <= 3.0\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(0.2, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.4, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8, 0.5833333333333334, 'x[3] <= 1.75\ngini = 0.102\nsamples = 37\nvalue = [0, 2, 35]'),
#  Text(0.7, 0.4166666666666667, 'x[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.6, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
# ...

# %% [markdown]
# # In scikit-learn, the binary search algorithm is used to find the optimal threshold value for each continuous feature in a decision tree.

# %%
import graphviz 
dot_data = tree.export_graphviz(DT, out_file=None) 
graph = graphviz.Source(dot_data) 
graph.render("DT_CLASS")
# Out:
# 'DT_CLASS.pdf'

# %%
dot_data = tree.export_graphviz(DT, out_file=None,feature_names=iris.feature_names,class_names=iris.target_names,filled=True, rounded=True,special_characters=True)  
graph = graphviz.Source(dot_data)  
graph

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier(n_estimators=1000)
RF = RF.fit(X_train,Y_train)

# %%
RF.score(X_test,Y_test)
# Out:
# 1.0

# %%
tree.plot_tree(DT)
# Out:
# [Text(0.4, 0.9166666666666666, 'x[2] <= 2.45\ngini = 0.666\nsamples = 120\nvalue = [41, 41, 38]'),
#  Text(0.3, 0.75, 'gini = 0.0\nsamples = 41\nvalue = [41, 0, 0]'),
#  Text(0.5, 0.75, 'x[2] <= 4.95\ngini = 0.499\nsamples = 79\nvalue = [0, 41, 38]'),
#  Text(0.2, 0.5833333333333334, 'x[3] <= 1.65\ngini = 0.133\nsamples = 42\nvalue = [0, 39, 3]'),
#  Text(0.1, 0.4166666666666667, 'gini = 0.0\nsamples = 38\nvalue = [0, 38, 0]'),
#  Text(0.3, 0.4166666666666667, 'x[1] <= 3.0\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(0.2, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.4, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8, 0.5833333333333334, 'x[3] <= 1.75\ngini = 0.102\nsamples = 37\nvalue = [0, 2, 35]'),
#  Text(0.7, 0.4166666666666667, 'x[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.6, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
# ...

# %% [markdown]
# If we run this code mutiple times we will found multiples results, for conclusion both random forest and decision tree gives us good results.

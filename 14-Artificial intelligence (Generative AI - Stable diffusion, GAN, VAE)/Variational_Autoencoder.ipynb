# %%
# !git clone https://github.com/davidADSP/Generative_Deep_Learning_2nd_Edition
# Out:
# Cloning into 'Generative_Deep_Learning_2nd_Edition'...
# remote: Enumerating objects: 635, done.
# remote: Counting objects: 100% (71/71), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 635 (delta 28), reused 26 (delta 21), pack-reused 564
# Receiving objects: 100% (635/635), 37.10 MiB | 11.53 MiB/s, done.
# Resolving deltas: 100% (357/357), done.

# %%
import os
os.chdir('/content/Generative_Deep_Learning_2nd_Edition/notebooks/03_vae/03_vae_faces')

# %%
# !pip install -r requirements.txt
# Out:
# Collecting matplotlib==3.6.3 (from -r requirements.txt (line 1))
#   Downloading matplotlib-3.6.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 70.7 MB/s eta 0:00:00
# Collecting jupyterlab==3.5.3 (from -r requirements.txt (line 2))
#   Downloading jupyterlab-3.5.3-py3-none-any.whl (8.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 69.4 MB/s eta 0:00:00
# Collecting scipy==1.10.0 (from -r requirements.txt (line 3))
#   Downloading scipy-1.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 15.8 MB/s eta 0:00:00
# Collecting scikit-learn==1.2.1 (from -r requirements.txt (line 4))
#   Downloading scikit_learn-1.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 65.6 MB/s eta 0:00:00
# Requirement already satisfied: scikit-image==0.19.3 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 5)) (0.19.3)
# Requirement already satisfied: pandas==1.5.3 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 6)) (1.5.3)
# Requirement already satisfied: music21==8.1.0 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 7)) (8.1.0)
# Collecting black[jupyter]==23.1.0 (from -r requirements.txt (line 8))
#   Downloading black-23.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 88.3 MB/s eta 0:00:00
# Collecting click==8.0.4 (from -r requirements.txt (line 9))
#   Downloading click-8.0.4-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 kB 13.8 MB/s eta 0:00:00
# Collecting flake8==5.0.4 (from -r requirements.txt (line 10))
#   Downloading flake8-5.0.4-py2.py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 8.5 MB/s eta 0:00:00
# Collecting kaggle==1.5.12 (from -r requirements.txt (line 11))
#   Downloading kaggle-1.5.12.tar.gz (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.0/59.0 kB 8.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pydot==1.4.2 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 12)) (1.4.2)
# Collecting ipywidgets==8.0.4 (from -r requirements.txt (line 13))
#   Downloading ipywidgets-8.0.4-py3-none-any.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.8/137.8 kB 19.9 MB/s eta 0:00:00
# Collecting tensorflow==2.10.1 (from -r requirements.txt (line 14))
#   Downloading tensorflow-2.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (578.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 578.1/578.1 MB 3.0 MB/s eta 0:00:00
# Collecting tensorboard==2.10.1 (from -r requirements.txt (line 15))
#   Downloading tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 62.2 MB/s eta 0:00:00
# Collecting tensorflow_probability==0.18.0 (from -r requirements.txt (line 16))
#   Downloading tensorflow_probability-0.18.0-py2.py3-none-any.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 3.4 MB/s eta 0:00:00
# Collecting flake8-nb==0.5.2 (from -r requirements.txt (line 17))
#   Downloading flake8_nb-0.5.2-py3-none-any.whl (23 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.6.3->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.6.3->-r requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.6.3->-r requirements.txt (line 1)) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.6.3->-r requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.6.3->-r requirements.txt (line 1)) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.6.3->-r requirements.txt (line 1)) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.6.3->-r requirements.txt (line 1)) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.6.3->-r requirements.txt (line 1)) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.6.3->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from jupyterlab==3.5.3->-r requirements.txt (line 2)) (7.34.0)
# Requirement already satisfied: tornado>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyterlab==3.5.3->-r requirements.txt (line 2)) (6.3.1)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.10/dist-packages (from jupyterlab==3.5.3->-r requirements.txt (line 2)) (5.3.1)
# Collecting jupyterlab-server~=2.10 (from jupyterlab==3.5.3->-r requirements.txt (line 2))
#   Downloading jupyterlab_server-2.23.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: jupyter-server<3,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from jupyterlab==3.5.3->-r requirements.txt (line 2)) (1.24.0)
# Collecting nbclassic (from jupyterlab==3.5.3->-r requirements.txt (line 2))
#   Downloading nbclassic-1.0.0-py3-none-any.whl (10.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 95.7 MB/s eta 0:00:00
# Requirement already satisfied: notebook<7 in /usr/local/lib/python3.10/dist-packages (from jupyterlab==3.5.3->-r requirements.txt (line 2)) (6.4.8)
# Requirement already satisfied: jinja2>=2.1 in /usr/local/lib/python3.10/dist-packages (from jupyterlab==3.5.3->-r requirements.txt (line 2)) (3.1.2)
# Requirement already satisfied: tomli in /usr/local/lib/python3.10/dist-packages (from jupyterlab==3.5.3->-r requirements.txt (line 2)) (2.0.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.2.1->-r requirements.txt (line 4)) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.2.1->-r requirements.txt (line 4)) (3.1.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.19.3->-r requirements.txt (line 5)) (3.1)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.19.3->-r requirements.txt (line 5)) (2.25.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.19.3->-r requirements.txt (line 5)) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.19.3->-r requirements.txt (line 5)) (1.4.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==1.5.3->-r requirements.txt (line 6)) (2022.7.1)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from music21==8.1.0->-r requirements.txt (line 7)) (4.0.0)
# Requirement already satisfied: jsonpickle in /usr/local/lib/python3.10/dist-packages (from music21==8.1.0->-r requirements.txt (line 7)) (3.0.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from music21==8.1.0->-r requirements.txt (line 7)) (9.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from music21==8.1.0->-r requirements.txt (line 7)) (2.27.1)
# Requirement already satisfied: webcolors>=1.5 in /usr/local/lib/python3.10/dist-packages (from music21==8.1.0->-r requirements.txt (line 7)) (1.13)
# Collecting mypy-extensions>=0.4.3 (from black[jupyter]==23.1.0->-r requirements.txt (line 8))
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting pathspec>=0.9.0 (from black[jupyter]==23.1.0->-r requirements.txt (line 8))
#   Downloading pathspec-0.11.1-py3-none-any.whl (29 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/dist-packages (from black[jupyter]==23.1.0->-r requirements.txt (line 8)) (3.7.0)
# Collecting tokenize-rt>=3.2.0 (from black[jupyter]==23.1.0->-r requirements.txt (line 8))
#   Downloading tokenize_rt-5.1.0-py2.py3-none-any.whl (5.8 kB)
# Collecting mccabe<0.8.0,>=0.7.0 (from flake8==5.0.4->-r requirements.txt (line 10))
#   Downloading mccabe-0.7.0-py2.py3-none-any.whl (7.3 kB)
# Collecting pycodestyle<2.10.0,>=2.9.0 (from flake8==5.0.4->-r requirements.txt (line 10))
#   Downloading pycodestyle-2.9.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.5/41.5 kB 6.2 MB/s eta 0:00:00
# Collecting pyflakes<2.6.0,>=2.5.0 (from flake8==5.0.4->-r requirements.txt (line 10))
#   Downloading pyflakes-2.5.0-py2.py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.1/66.1 kB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle==1.5.12->-r requirements.txt (line 11)) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle==1.5.12->-r requirements.txt (line 11)) (2023.5.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle==1.5.12->-r requirements.txt (line 11)) (4.65.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle==1.5.12->-r requirements.txt (line 11)) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle==1.5.12->-r requirements.txt (line 11)) (1.26.16)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets==8.0.4->-r requirements.txt (line 13)) (5.5.6)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets==8.0.4->-r requirements.txt (line 13)) (5.7.1)
# Collecting widgetsnbextension~=4.0 (from ipywidgets==8.0.4->-r requirements.txt (line 13))
#   Downloading widgetsnbextension-4.0.8-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 64.2 MB/s eta 0:00:00
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets==8.0.4->-r requirements.txt (line 13)) (3.0.7)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.1->-r requirements.txt (line 14)) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.1->-r requirements.txt (line 14)) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.1->-r requirements.txt (line 14)) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.1->-r requirements.txt (line 14)) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.1->-r requirements.txt (line 14)) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.1->-r requirements.txt (line 14)) (1.56.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.1->-r requirements.txt (line 14)) (3.8.0)
# Collecting keras<2.11,>=2.10.0 (from tensorflow==2.10.1->-r requirements.txt (line 14))
#   Downloading keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 96.1 MB/s eta 0:00:00
# Collecting keras-preprocessing>=1.1.1 (from tensorflow==2.10.1->-r requirements.txt (line 14))
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.1->-r requirements.txt (line 14)) (16.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.1->-r requirements.txt (line 14)) (3.3.0)
# Collecting protobuf<3.20,>=3.9.2 (from tensorflow==2.10.1->-r requirements.txt (line 14))
#   Downloading protobuf-3.19.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 15.1 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.1->-r requirements.txt (line 14)) (67.7.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.1->-r requirements.txt (line 14)) (0.32.0)
# Collecting tensorflow-estimator<2.11,>=2.10.0 (from tensorflow==2.10.1->-r requirements.txt (line 14))
#   Downloading tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.7/438.7 kB 49.6 MB/s eta 0:00:00
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.1->-r requirements.txt (line 14)) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.1->-r requirements.txt (line 14)) (4.6.3)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.1->-r requirements.txt (line 14)) (1.14.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.10.1->-r requirements.txt (line 15)) (2.17.3)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard==2.10.1->-r requirements.txt (line 15))
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.10.1->-r requirements.txt (line 15)) (3.4.3)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard==2.10.1->-r requirements.txt (line 15))
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 118.1 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard==2.10.1->-r requirements.txt (line 15))
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 75.4 MB/s eta 0:00:00
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.10.1->-r requirements.txt (line 15)) (2.3.6)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.10.1->-r requirements.txt (line 15)) (0.40.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from tensorflow_probability==0.18.0->-r requirements.txt (line 16)) (4.4.2)
# Requirement already satisfied: cloudpickle>=1.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow_probability==0.18.0->-r requirements.txt (line 16)) (2.2.1)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from tensorflow_probability==0.18.0->-r requirements.txt (line 16)) (0.1.8)
# Requirement already satisfied: nbconvert>=5.6.0 in /usr/local/lib/python3.10/dist-packages (from flake8-nb==0.5.2->-r requirements.txt (line 17)) (6.5.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.10.1->-r requirements.txt (line 15)) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.10.1->-r requirements.txt (line 15)) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.10.1->-r requirements.txt (line 15)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.10.1->-r requirements.txt (line 15)) (1.3.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets==8.0.4->-r requirements.txt (line 13)) (0.2.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets==8.0.4->-r requirements.txt (line 13)) (6.1.12)
# Collecting jedi>=0.16 (from ipython->jupyterlab==3.5.3->-r requirements.txt (line 2))
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 43.2 MB/s eta 0:00:00
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->jupyterlab==3.5.3->-r requirements.txt (line 2)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->jupyterlab==3.5.3->-r requirements.txt (line 2)) (3.0.38)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->jupyterlab==3.5.3->-r requirements.txt (line 2)) (2.14.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->jupyterlab==3.5.3->-r requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->jupyterlab==3.5.3->-r requirements.txt (line 2)) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->jupyterlab==3.5.3->-r requirements.txt (line 2)) (4.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.1->jupyterlab==3.5.3->-r requirements.txt (line 2)) (2.1.3)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.5.3->-r requirements.txt (line 2)) (3.7.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.5.3->-r requirements.txt (line 2)) (21.3.0)
# Requirement already satisfied: nbformat>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.5.3->-r requirements.txt (line 2)) (5.9.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.5.3->-r requirements.txt (line 2)) (0.17.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.5.3->-r requirements.txt (line 2)) (23.2.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.5.3->-r requirements.txt (line 2)) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.5.3->-r requirements.txt (line 2)) (0.17.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.5.3->-r requirements.txt (line 2)) (1.6.0)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.10/dist-packages (from jupyterlab-server~=2.10->jupyterlab==3.5.3->-r requirements.txt (line 2)) (2.12.1)
# Collecting json5>=0.9.0 (from jupyterlab-server~=2.10->jupyterlab==3.5.3->-r requirements.txt (line 2))
#   Downloading json5-0.9.14-py2.py3-none-any.whl (19 kB)
# Collecting jsonschema>=4.17.3 (from jupyterlab-server~=2.10->jupyterlab==3.5.3->-r requirements.txt (line 2))
#   Downloading jsonschema-4.18.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 11.8 MB/s eta 0:00:00
# Collecting requests (from music21==8.1.0->-r requirements.txt (line 7))
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5.6.0->flake8-nb==0.5.2->-r requirements.txt (line 17)) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5.6.0->flake8-nb==0.5.2->-r requirements.txt (line 17)) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5.6.0->flake8-nb==0.5.2->-r requirements.txt (line 17)) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5.6.0->flake8-nb==0.5.2->-r requirements.txt (line 17)) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5.6.0->flake8-nb==0.5.2->-r requirements.txt (line 17)) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5.6.0->flake8-nb==0.5.2->-r requirements.txt (line 17)) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5.6.0->flake8-nb==0.5.2->-r requirements.txt (line 17)) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5.6.0->flake8-nb==0.5.2->-r requirements.txt (line 17)) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5.6.0->flake8-nb==0.5.2->-r requirements.txt (line 17)) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5.6.0->flake8-nb==0.5.2->-r requirements.txt (line 17)) (1.2.1)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook<7->jupyterlab==3.5.3->-r requirements.txt (line 2)) (1.5.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->music21==8.1.0->-r requirements.txt (line 7)) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->music21==8.1.0->-r requirements.txt (line 7)) (3.4)
# Collecting notebook-shim>=0.2.3 (from nbclassic->jupyterlab==3.5.3->-r requirements.txt (line 2))
#   Downloading notebook_shim-0.2.3-py3-none-any.whl (13 kB)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle==1.5.12->-r requirements.txt (line 11)) (1.3)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab==3.5.3->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab==3.5.3->-r requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->jupyterlab==3.5.3->-r requirements.txt (line 2)) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.10->jupyterlab==3.5.3->-r requirements.txt (line 2)) (23.1.0)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=4.17.3->jupyterlab-server~=2.10->jupyterlab==3.5.3->-r requirements.txt (line 2))
#   Downloading jsonschema_specifications-2023.6.1-py3-none-any.whl (17 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=4.17.3->jupyterlab-server~=2.10->jupyterlab==3.5.3->-r requirements.txt (line 2))
#   Downloading referencing-0.29.1-py3-none-any.whl (25 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=4.17.3->jupyterlab-server~=2.10->jupyterlab==3.5.3->-r requirements.txt (line 2))
#   Downloading rpds_py-0.8.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 84.0 MB/s eta 0:00:00
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.2.0->jupyter-server<3,>=1.16.0->jupyterlab==3.5.3->-r requirements.txt (line 2)) (2.17.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->jupyterlab==3.5.3->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyterlab==3.5.3->-r requirements.txt (line 2)) (0.2.6)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard==2.10.1->-r requirements.txt (line 15)) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.10.1->-r requirements.txt (line 15)) (3.2.2)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->jupyter-server<3,>=1.16.0->jupyterlab==3.5.3->-r requirements.txt (line 2)) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5.6.0->flake8-nb==0.5.2->-r requirements.txt (line 17)) (2.4.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5.6.0->flake8-nb==0.5.2->-r requirements.txt (line 17)) (0.5.1)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=1.16.0->jupyterlab==3.5.3->-r requirements.txt (line 2)) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=1.16.0->jupyterlab==3.5.3->-r requirements.txt (line 2)) (2.21)
# Building wheels for collected packages: kaggle
#   Building wheel for kaggle (setup.py) ... done
#   Created wheel for kaggle: filename=kaggle-1.5.12-py3-none-any.whl size=73031 sha256=7de49b84d9a563be8226a6dac8b4eea1a0d98452b52fb71938f09a8ec091fac8
#   Stored in directory: /root/.cache/pip/wheels/70/0c/e6/79103212a102e78b8453691b905f48000219574ba7137e7207
# Successfully built kaggle
# Installing collected packages: tensorboard-plugin-wit, keras, json5, widgetsnbextension, tokenize-rt, tensorflow_probability, tensorflow-estimator, tensorboard-data-server, scipy, rpds-py, requests, pyflakes, pycodestyle, protobuf, pathspec, mypy-extensions, mccabe, keras-preprocessing, jedi, click, scikit-learn, referencing, matplotlib, kaggle, flake8, black, jsonschema-specifications, google-auth-oauthlib, tensorboard, jsonschema, ipywidgets, tensorflow, flake8-nb, notebook-shim, jupyterlab-server, nbclassic, jupyterlab
#   Attempting uninstall: keras
#     Found existing installation: keras 2.12.0
#     Uninstalling keras-2.12.0:
#       Successfully uninstalled keras-2.12.0
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.4
#     Uninstalling widgetsnbextension-3.6.4:
#       Successfully uninstalled widgetsnbextension-3.6.4
#   Attempting uninstall: tensorflow_probability
#     Found existing installation: tensorflow-probability 0.20.1
#     Uninstalling tensorflow-probability-0.20.1:
#       Successfully uninstalled tensorflow-probability-0.20.1
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.12.0
#     Uninstalling tensorflow-estimator-2.12.0:
#       Successfully uninstalled tensorflow-estimator-2.12.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.1
#     Uninstalling tensorboard-data-server-0.7.1:
#       Successfully uninstalled tensorboard-data-server-0.7.1
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.10.1
#     Uninstalling scipy-1.10.1:
#       Successfully uninstalled scipy-1.10.1
#   Attempting uninstall: requests
#     Found existing installation: requests 2.27.1
#     Uninstalling requests-2.27.1:
#       Successfully uninstalled requests-2.27.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: click
#     Found existing installation: click 8.1.3
#     Uninstalling click-8.1.3:
#       Successfully uninstalled click-8.1.3
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
#   Attempting uninstall: kaggle
#     Found existing installation: kaggle 1.5.13
#     Uninstalling kaggle-1.5.13:
#       Successfully uninstalled kaggle-1.5.13
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.0.0
#     Uninstalling google-auth-oauthlib-1.0.0:
#       Successfully uninstalled google-auth-oauthlib-1.0.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.12.3
#     Uninstalling tensorboard-2.12.3:
#       Successfully uninstalled tensorboard-2.12.3
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.3.3
#     Uninstalling jsonschema-4.3.3:
#       Successfully uninstalled jsonschema-4.3.3
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.12.0
#     Uninstalling tensorflow-2.12.0:
#       Successfully uninstalled tensorflow-2.12.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.27.1, but you have requests 2.31.0 which is incompatible.
# tensorflow-datasets 4.9.2 requires protobuf>=3.20, but you have protobuf 3.19.6 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 3.19.6 which is incompatible.
# Successfully installed black-23.1.0 click-8.0.4 flake8-5.0.4 flake8-nb-0.5.2 google-auth-oauthlib-0.4.6 ipywidgets-8.0.4 jedi-0.18.2 json5-0.9.14 jsonschema-4.18.0 jsonschema-specifications-2023.6.1 jupyterlab-3.5.3 jupyterlab-server-2.23.0 kaggle-1.5.12 keras-2.10.0 keras-preprocessing-1.1.2 matplotlib-3.6.3 mccabe-0.7.0 mypy-extensions-1.0.0 nbclassic-1.0.0 notebook-shim-0.2.3 pathspec-0.11.1 protobuf-3.19.6 pycodestyle-2.9.1 pyflakes-2.5.0 referencing-0.29.1 requests-2.31.0 rpds-py-0.8.8 scikit-learn-1.2.1 scipy-1.10.0 tensorboard-2.10.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.10.1 tensorflow-estimator-2.10.0 tensorflow_probability-0.18.0 tokenize-rt-5.1.0 widgetsnbextension-4.0.8

# %%
# !pip install vae_utils
# Out:
# ERROR: Could not find a version that satisfies the requirement vae_utils (from versions: none)
# ERROR: No matching distribution found for vae_utils

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras import (
    layers,
    models,
    callbacks,
    utils,
    metrics,
    losses,
    optimizers,
)

from scipy.stats import norm
import pandas as pd

from notebooks.utils import sample_batch, display

from vae_utils import get_vector_from_label, add_vector_to_images, morph_faces
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
IMAGE_SIZE = 64
CHANNELS = 3
BATCH_SIZE = 128
NUM_FEATURES = 64
Z_DIM = 200
LEARNING_RATE = 0.0005
EPOCHS = 10
BETA = 2000
LOAD_MODEL = False

# %%
# !git clone https://github.com/Hvdogra/img_align_celeba
# Out:
# Cloning into 'img_align_celeba'...
# remote: Enumerating objects: 202470, done.
# remote: Total 202470 (delta 0), reused 0 (delta 0), pack-reused 202470
# Receiving objects: 100% (202470/202470), 1.29 GiB | 18.09 MiB/s, done.
# Updating files: 100% (202599/202599), done.

# %%
# Load the data
train_data = utils.image_dataset_from_directory(
    "/content/Generative_Deep_Learning_2nd_Edition/notebooks/03_vae/03_vae_faces/img_align_celeba",
    labels=None,
    color_mode="rgb",
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=42,
    interpolation="bilinear",
)
# Out:
# Found 202599 files belonging to 1 classes.

# %%
# Preprocess the data
def preprocess(img):
    img = tf.cast(img, "float32") / 255.0
    return img


train = train_data.map(lambda x: preprocess(x))

# %%
train_sample = sample_batch(train)

# %%
# Show some faces from the training set
display(train_sample, cmap=None)

# %%
class Sampling(layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = K.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
# Encoder
encoder_input = layers.Input(
    shape=(IMAGE_SIZE, IMAGE_SIZE, CHANNELS), name="encoder_input"
)
x = layers.Conv2D(NUM_FEATURES, kernel_size=3, strides=2, padding="same")(
    encoder_input
)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(NUM_FEATURES, kernel_size=3, strides=2, padding="same")(x)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(NUM_FEATURES, kernel_size=3, strides=2, padding="same")(x)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(NUM_FEATURES, kernel_size=3, strides=2, padding="same")(x)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(NUM_FEATURES, kernel_size=3, strides=2, padding="same")(x)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)
shape_before_flattening = K.int_shape(x)[1:]  # the decoder will need this!

x = layers.Flatten()(x)
z_mean = layers.Dense(Z_DIM, name="z_mean")(x)
z_log_var = layers.Dense(Z_DIM, name="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])

encoder = models.Model(encoder_input, [z_mean, z_log_var, z], name="encoder")
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_input (InputLayer)     [(None, 64, 64, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 32, 32, 64)   1792        ['encoder_input[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 64)  256         ['conv2d[0][0]']
#  alization)
#
#  leaky_re_lu (LeakyReLU)        (None, 32, 32, 64)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 16, 16, 64)   36928       ['leaky_re_lu[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 16, 16, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 16, 16, 64)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 8, 8, 64)     36928       ['leaky_re_lu_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 8, 8, 64)    256         ['conv2d_2[0][0]']
#  rmalization)
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 8, 8, 64)     0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 4, 4, 64)     36928       ['leaky_re_lu_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 4, 4, 64)    256         ['conv2d_3[0][0]']
#  rmalization)
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 4, 4, 64)     0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 2, 2, 64)     36928       ['leaky_re_lu_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 2, 2, 64)    256         ['conv2d_4[0][0]']
#  rmalization)
#
#  leaky_re_lu_4 (LeakyReLU)      (None, 2, 2, 64)     0           ['batch_normalization_4[0][0]']
#
#  flatten (Flatten)              (None, 256)          0           ['leaky_re_lu_4[0][0]']
#
#  z_mean (Dense)                 (None, 200)          51400       ['flatten[0][0]']
#
#  z_log_var (Dense)              (None, 200)          51400       ['flatten[0][0]']
#
#  sampling (Sampling)            (None, 200)          0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 253,584
# Trainable params: 252,944
# Non-trainable params: 640
# __________________________________________________________________________________________________

# %%
# Decoder
decoder_input = layers.Input(shape=(Z_DIM,), name="decoder_input")
x = layers.Dense(np.prod(shape_before_flattening))(decoder_input)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)
x = layers.Reshape(shape_before_flattening)(x)
x = layers.Conv2DTranspose(
    NUM_FEATURES, kernel_size=3, strides=2, padding="same"
)(x)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2DTranspose(
    NUM_FEATURES, kernel_size=3, strides=2, padding="same"
)(x)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2DTranspose(
    NUM_FEATURES, kernel_size=3, strides=2, padding="same"
)(x)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2DTranspose(
    NUM_FEATURES, kernel_size=3, strides=2, padding="same"
)(x)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2DTranspose(
    NUM_FEATURES, kernel_size=3, strides=2, padding="same"
)(x)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)
decoder_output = layers.Conv2DTranspose(
    CHANNELS, kernel_size=3, strides=1, activation="sigmoid", padding="same"
)(x)
decoder = models.Model(decoder_input, decoder_output)
decoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  decoder_input (InputLayer)  [(None, 200)]             0
#
#  dense (Dense)               (None, 256)               51456
#
#  batch_normalization_5 (Batc  (None, 256)              1024
#  hNormalization)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 256)               0
#
#  reshape (Reshape)           (None, 2, 2, 64)          0
#
#  conv2d_transpose (Conv2DTra  (None, 4, 4, 64)         36928
#  nspose)
#
#  batch_normalization_6 (Batc  (None, 4, 4, 64)         256
#  hNormalization)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 4, 4, 64)          0
#
#  conv2d_transpose_1 (Conv2DT  (None, 8, 8, 64)         36928
#  ranspose)
#
#  batch_normalization_7 (Batc  (None, 8, 8, 64)         256
#  hNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 8, 8, 64)          0
#
#  conv2d_transpose_2 (Conv2DT  (None, 16, 16, 64)       36928
#  ranspose)
#
#  batch_normalization_8 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 16, 16, 64)        0
#
#  conv2d_transpose_3 (Conv2DT  (None, 32, 32, 64)       36928
#  ranspose)
#
#  batch_normalization_9 (Batc  (None, 32, 32, 64)       256
#  hNormalization)
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 32, 32, 64)        0
#
#  conv2d_transpose_4 (Conv2DT  (None, 64, 64, 64)       36928
#  ranspose)
#
#  batch_normalization_10 (Bat  (None, 64, 64, 64)       256
#  chNormalization)
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 64, 64, 64)        0
#
#  conv2d_transpose_5 (Conv2DT  (None, 64, 64, 3)        1731
#  ranspose)
#
# =================================================================
# Total params: 240,131
# Trainable params: 238,979
# Non-trainable params: 1,152
# _________________________________________________________________

# %%
class VAE(models.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def call(self, inputs):
        """Call the model on a particular input."""
        z_mean, z_log_var, z = encoder(inputs)
        reconstruction = decoder(z)
        return z_mean, z_log_var, reconstruction

    def train_step(self, data):
        """Step run during training."""
        with tf.GradientTape() as tape:
            z_mean, z_log_var, reconstruction = self(data, training=True)
            reconstruction_loss = tf.reduce_mean(
                BETA * losses.mean_squared_error(data, reconstruction)
            )
            kl_loss = tf.reduce_mean(
                tf.reduce_sum(
                    -0.5
                    * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var)),
                    axis=1,
                )
            )
            total_loss = reconstruction_loss + kl_loss

        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))

        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)

        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

    def test_step(self, data):
        """Step run during validation."""
        if isinstance(data, tuple):
            data = data[0]

        z_mean, z_log_var, reconstruction = self(data)
        reconstruction_loss = tf.reduce_mean(
            BETA * losses.mean_squared_error(data, reconstruction)
        )
        kl_loss = tf.reduce_mean(
            tf.reduce_sum(
                -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var)),
                axis=1,
            )
        )
        total_loss = reconstruction_loss + kl_loss

        return {
            "loss": total_loss,
            "reconstruction_loss": reconstruction_loss,
            "kl_loss": kl_loss,
        }

# %%
# Create a variational autoencoder
vae = VAE(encoder, decoder)

# %%
# Compile the variational autoencoder
optimizer = optimizers.Adam(learning_rate=LEARNING_RATE)
vae.compile(optimizer=optimizer)

# %%
# Create a model save checkpoint
model_checkpoint_callback = callbacks.ModelCheckpoint(
    filepath="./checkpoint",
    save_weights_only=False,
    save_freq="epoch",
    monitor="loss",
    mode="min",
    save_best_only=True,
    verbose=0,
)

tensorboard_callback = callbacks.TensorBoard(log_dir="./logs")


class ImageGenerator(callbacks.Callback):
    def __init__(self, num_img, latent_dim):
        self.num_img = num_img
        self.latent_dim = latent_dim

    def on_epoch_end(self, epoch, logs=None):
        random_latent_vectors = tf.random.normal(
            shape=(self.num_img, self.latent_dim)
        )
        generated_images = self.model.decoder(random_latent_vectors)
        generated_images *= 255
        generated_images.numpy()
        for i in range(self.num_img):
            img = utils.array_to_img(generated_images[i])
            img.save("./output/generated_img_%03d_%d.png" % (epoch, i))

# %%
# Load old weights if required
if LOAD_MODEL:
    vae.load_weights("./models/vae")
    tmp = vae.predict(train.take(1))

# %%
vae.fit(
    train,
    epochs=EPOCHS,
    callbacks=[
        model_checkpoint_callback,
        tensorboard_callback,
        ImageGenerator(num_img=10, latent_dim=Z_DIM),
    ],
)
# Out:
# Epoch 1/10
# 1583/1583 [==============================] - ETA: 0s - loss: 103.4837 - reconstruction_loss: 70.1806 - kl_loss: 14.7667
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 11). These functions will not be directly callable after loading.
# 1583/1583 [==============================] - 155s 89ms/step - loss: 103.4720 - reconstruction_loss: 70.1806 - kl_loss: 14.7667
# Epoch 2/10
# 1583/1583 [==============================] - ETA: 0s - loss: 71.9272 - reconstruction_loss: 55.7524 - kl_loss: 14.9405
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 11). These functions will not be directly callable after loading.
# 1583/1583 [==============================] - 133s 84ms/step - loss: 71.9264 - reconstruction_loss: 55.7524 - kl_loss: 14.9405
# Epoch 3/10
# 1583/1583 [==============================] - ETA: 0s - loss: 68.2627 - reconstruction_loss: 51.9933 - kl_loss: 15.8046
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 11). These functions will not be directly callable after loading.
# 1583/1583 [==============================] - 133s 84ms/step - loss: 68.2624 - reconstruction_loss: 51.9933 - kl_loss: 15.8046
# Epoch 4/10
# 1583/1583 [==============================] - ETA: 0s - loss: 66.7612 - reconstruction_loss: 50.1653 - kl_loss: 16.2674
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 11). These functions will not be directly callable after loading.
# 1583/1583 [==============================] - 133s 84ms/step - loss: 66.7610 - reconstruction_loss: 50.1653 - kl_loss: 16.2674
# Epoch 5/10
# 1583/1583 [==============================] - ETA: 0s - loss: 65.7001 - reconstruction_loss: 48.9327 - kl_loss: 16.5870
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 11). These functions will not be directly callable after loading.
# 1583/1583 [==============================] - 129s 81ms/step - loss: 65.7000 - reconstruction_loss: 48.9327 - kl_loss: 16.5870
# Epoch 6/10
# 1582/1583 [============================>.] - ETA: 0s - loss: 65.1675 - reconstruction_loss: 48.2293 - kl_loss: 16.7925
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 11). These functions will not be directly callable after loading.
# 1583/1583 [==============================] - 140s 88ms/step - loss: 65.1673 - reconstruction_loss: 48.2321 - kl_loss: 16.7925
# Epoch 7/10
# 1583/1583 [==============================] - ETA: 0s - loss: 64.8523 - reconstruction_loss: 47.7785 - kl_loss: 16.9434
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 11). These functions will not be directly callable after loading.
# 1583/1583 [==============================] - 132s 83ms/step - loss: 64.8522 - reconstruction_loss: 47.7785 - kl_loss: 16.9434
# Epoch 8/10
# 1583/1583 [==============================] - ETA: 0s - loss: 64.5782 - reconstruction_loss: 47.4404 - kl_loss: 17.0304
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 11). These functions will not be directly callable after loading.
# 1583/1583 [==============================] - 129s 81ms/step - loss: 64.5781 - reconstruction_loss: 47.4404 - kl_loss: 17.0304
# Epoch 9/10
# 1583/1583 [==============================] - ETA: 0s - loss: 64.4111 - reconstruction_loss: 47.1568 - kl_loss: 17.1510
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 11). These functions will not be directly callable after loading.
# 1583/1583 [==============================] - 131s 83ms/step - loss: 64.4110 - reconstruction_loss: 47.1568 - kl_loss: 17.1510
# Epoch 10/10
# 1583/1583 [==============================] - ETA: 0s - loss: 64.2185 - reconstruction_loss: 46.8970 - kl_loss: 17.2102
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 11). These functions will not be directly callable after loading.
# 1583/1583 [==============================] - 130s 82ms/step - loss: 64.2185 - reconstruction_loss: 46.8970 - kl_loss: 17.2102

# %%
# Save the final models
vae.save("./models/vae")
encoder.save("./models/encoder")
decoder.save("./models/decoder")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 11). These functions will not be directly callable after loading.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.

# %%
# Select a subset of the test set
batches_to_predict = 1
example_images = np.array(
    list(train.take(batches_to_predict).get_single_element())
)

# %%
# Create autoencoder predictions and display
z_mean, z_log_var, reconstructions = vae.predict(example_images)
print("Example real faces")
display(example_images)
print("Reconstructions")
display(reconstructions)
# Out:
# 4/4 [==============================] - 1s 9ms/step
# Example real faces
# Reconstructions

# %%
_, _, z = vae.encoder.predict(example_images)

x = np.linspace(-3, 3, 100)

fig = plt.figure(figsize=(20, 5))
fig.subplots_adjust(hspace=0.6, wspace=0.4)

for i in range(50):
    ax = fig.add_subplot(5, 10, i + 1)
    ax.hist(z[:, i], density=True, bins=20)
    ax.axis("off")
    ax.text(
        0.5, -0.35, str(i), fontsize=10, ha="center", transform=ax.transAxes
    )
    ax.plot(x, norm.pdf(x))

plt.show()
# Out:
# 4/4 [==============================] - 0s 11ms/step

# %%
# Sample some points in the latent space, from the standard normal distribution
grid_width, grid_height = (10, 3)
z_sample = np.random.normal(size=(grid_width * grid_height, Z_DIM))

# %%
# Decode the sampled points
reconstructions = decoder.predict(z_sample)
# Out:
# 1/1 [==============================] - 0s 489ms/step

# %%
# Draw a plot of decoded images
fig = plt.figure(figsize=(18, 5))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

# Output the grid of faces
for i in range(grid_width * grid_height):
    ax = fig.add_subplot(grid_height, grid_width, i + 1)
    ax.axis("off")
    ax.imshow(reconstructions[i, :, :])
